# %% [markdown]
# <a href="https://colab.research.google.com/github/Xavier-ML/Curso-completo-de-Python-de-la-A-a-la-Z/blob/main/Tema01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # El inicio de una gran aventura

# %% [markdown]
# Pyratilla es un chico de 17 años que lleva deseando ser pirata desde que tiene uso de razón.
#
#
#
#
# ![pyartilla_inicios.png](data:image/png;base64,...)

# %% [markdown]
# Ahora que ha dejado de ser un niño, quiere empezar sus aventuras lo antes posible.
#
# Es cierto que va a empezar solamente con la compañía de su loro Pyo, pero está dispuesto a hacer todo lo que sea necesario para cumplir su sueño: convertirse en el pirata más famoso de todos sus tiempos.
#
# ![pyo.png](data:image/png;base64,...)

# %% [markdown]
# Y al igual que Pyratilla, no nos enrendemos más y empecemos esta aventura.
